# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from operator import add
from operator import sub
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# processing and uploading dataset
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['neuron data.csv']))
from google.colab import files
uploaded1 = files.upload()
uploaded2 = files.upload()
ERP = pd.read_csv(io.BytesIO(uploaded1['erpdata.csv']))
dem = pd.read_csv(io.BytesIO(uploaded2['demographic.csv']))

#time
time_points= 3072

#adding range of time
time=[]
for i in range(0, time_points):
    if ERP.iloc[i, 11] >= 0 and ERP.iloc[i, 11] <= 500:
        time.append(ERP.iloc[i, 11])

#taking the average of ERP data
def ERP_fin(electrode, group, task)
  for i in range(0, time_points)
    if ERP.iloc[i, 1]==1:
      task=1
    if ERP.iloc[i,1]==2:
      task=2
    if (ERP.iloc[i, 0]>=0 && ERP.iloc[i, 0]<=24):
      group=0
    elif (ERP.iloc[i,0]>=59 && ERP.iloc[i,0]<=66):
      group=0
    else:
      group=1
  return ERP_fin

#creating heatmap
sns.heatmap(df.set_index('Time (ms)').T, cbar_kws={'label': 'uV'})
plt.ylabel('electrode number')
plt.title('Average Event Related Potential for Patients in Condition 1')

# extracting features
x = []
for subject in range(0, 81):
    patient_x = []
    for e in range(1, 10):
        patient_x.append(min(patient_ERP(subject, e, 1))) 
        patient_x.append(max(patient_ERP(subject, e, 1))) 
        patient_x.append(min(patient_ERP(subject, e, 2))) 
        patient_x.append(max(patient_ERP(subject, e, 2))) 
    x.append(patient_x)

y = []
for patient in range(0, 81):
    y.append(demographic.iloc[patient, 1])
    
#train and test dataset  
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# importing algorithm from library
from sklearn import tree
# assigning to a variable
D_Tree = tree.DecisionTreeClassifier()
# train a model using train
D_Tree.fit(x_train,y_train)
# predicting accuracy of the model using X_test
predicted_Tree = D_Tree.predict(x_test)
# determining accuracy measurement of model
accuracy = metrics.accuracy_score(y_test,predicted_Tree)
print(accuracy)

#K-nearest neighbor
from sklearn.neighbors import KNeighborsClassifier
KNN=KNeighborsClassifier(n_neighbors=4)
KNN.fit(x_train, y_train)
predicted_KNN=KNN.predict(x_test)
accuracy=metrics.accuracy_score(y_test, predicted_KNN)
# Out:
#      <input type="file" id="files-c08ae168-913a-4e26-89b8-cb7de315b700" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c08ae168-913a-4e26-89b8-cb7de315b700">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
